# %% [markdown]
# <a href="https://colab.research.google.com/github/BrandoSor4/Data-Mining/blob/main/Soriano_Brando_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rename the notebook Lastname.Firstname-A1.ipynb
#
# 1. Download real estate listings for a town of your choice from redfin.com.
# 2. Load the data into a dataframe.
#
# 2 pts.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('refin.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-6b9f6007d58d> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 df = pd.read_csv('refin.csv')
#       5 print(df)
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df
# Out:
#       SALE TYPE         SOLD DATE              PROPERTY TYPE  \
# 0   MLS Listing               NaN  Single Family Residential
# 1   MLS Listing               NaN                Condo/Co-op
# 2   MLS Listing               NaN  Single Family Residential
# 3   MLS Listing               NaN  Single Family Residential
# 4   MLS Listing               NaN                Condo/Co-op
# 5   MLS Listing               NaN  Single Family Residential
# 6   MLS Listing               NaN  Single Family Residential
# 7   MLS Listing               NaN                Condo/Co-op
# 8   MLS Listing               NaN  Single Family Residential
# 9     PAST SALE      April-1-1983  Single Family Residential
# 10  MLS Listing               NaN                Condo/Co-op
# 11  MLS Listing               NaN                Condo/Co-op
# 12  MLS Listing               NaN                Vacant Land
# 13  MLS Listing               NaN  Single Family Residential
# ...

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# SALE TYPE                                                                                       0
# SOLD DATE                                                                                      44
# PROPERTY TYPE                                                                                   0
# ADDRESS                                                                                         0
# CITY                                                                                            0
# STATE OR PROVINCE                                                                               0
# ZIP OR POSTAL CODE                                                                              0
# PRICE                                                                                           0
# BEDS                                                                                            2
# BATHS                                                                                           3
# ...

# %% [markdown]
# 3. Evaluate data types and null values among the data
#
# 2 pts.

# %% [markdown]
# ### Sale type, Property type, the Address, City, State, Zip Code, Price of listing, How many days on the market, the Current Status of the home, the sourced URL, the listing sevice, longitude and latitude were data types with 0 null values. The data for Bed and Bath shared only a couple of null values. The data for lot sizes had 17 null values. There is seven data types with 40 or more null values out of 46 rows, meaining they are unable to be used in our modeling. There is missing data wether it has been mistakenly not filled in or no one has taken the measurements regarding the corresponding data of the house.

# %%
# Out:
#   File "<ipython-input-5-00d4f5551545>", line 2
#     Sale Type
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 4. Assess the range of values (min, max, quartiles) in each numeric field.
#
# 2 pts.

# %%
df.describe()
# Out:
#               PRICE       BEDS      BATHS  SQUARE FEET      LOT SIZE  \
# count  4.600000e+01  44.000000  43.000000     5.000000     29.000000
# mean   6.180827e+05   3.204545   2.046512  1518.200000   6069.551724
# std    2.785091e+05   1.339551   0.770080  1290.676451   2854.402922
# min    1.999000e+05   1.000000   1.000000   466.000000   2500.000000
# 25%    4.990000e+05   2.000000   1.500000   775.000000   4251.000000
# 50%    5.990000e+05   3.000000   2.000000   995.000000   5001.000000
# 75%    7.290000e+05   4.000000   2.500000  1667.000000   7501.000000
# max    2.000000e+06   7.000000   4.000000  3688.000000  15050.000000
#
#        YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# count         1.0       46.000000        5.00000        1.0
# mean       1930.0       69.434783      381.80000      280.0
# std           NaN       91.446074       76.88758        NaN
# min        1930.0        3.000000      268.00000      280.0
# ...

# %% [markdown]
# # Max Price for a home is 2000000/ Max amount of beds is 7 and 4 bathrooms/ Square footage maxes at 3688 square feet/ The max lot size is 15050, however is represented by 29 out of 46 houses, technically there can be a bigger lot size/ Days on Market can also be counted and the longest a home has been on the market is 495 days.
# ## The minimum price for a house is 199000, a big difference probably because of the lot size, number of bathrooms, baths, and amount of square footage/ The least amount of square footage in one of these homes is 466 square feet/ A minimum of 1 bed and 1 bath/ With a minimum of three days on the market which may not be parralell with the minimum values nessecsarily. I believe it would have been for a house near the 50% tile area of price.

# %% [markdown]
# 5. Assess the intercorrelations among the numeric features in the dataset using a heatmap.
#
# 2 pts.

# %% [markdown]
# ### The heat map standsout the null values as well as telss there is 0.0 correlation among any numeric data.

# %%
sns.heatmap(df.isnull(), cbar = True)
# Out:
# <Axes: >

# %% [markdown]
# 6. Assess intercorrelations among bedrooms and bathrooms using a jointplot.
#
# 2 pts.

# %%
sns.jointplot(x='BEDS', y='BATHS', data=df, kind='scatter')
plt.title('Scatter Plot of BEDS vs. BATHS')
plt.show()

# %% [markdown]
# ### A majority of homes have four bedroom and two bathrooms. It is hard to tell if there is a linear line.

# %% [markdown]
# Based on the results above answer the following questions using a separate text cell.
#
# 1. What is the target variable in this dataset? (2 pts.)
# ##The target variable is the selling price or value of the home.
# 2. Which fields have missing values and what is the proportion of missing values for each field (2 pts.)
# ## From the given data types the sold date, square footage, year built, price per square feet, Next open house start and end time all had jurassaic missing values over more than 40 out of 46 null values: whereas bedrooms (2 null), baths (3 null) and lot size(17 null)
# 3. Are there categorical features that are represented by numbers? (2 pts.)
#
# ## MLS# or Multiple Listing Service id number
#
# 4. Which (multinomial) fields would need to be dummy coded for modeling? (2 pts.)
# ## Status, State, City, Property type, and Sale type are all multinominal categoricale variables
# 5. Is there evidence of multicollinearity (correlation among features)? (2 pts.)
# Yes, there is evidence of multicollinearity in the dataset. In particular, Beds and Baths show a positive correlation.
